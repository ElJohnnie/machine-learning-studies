# %%
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import cross_val_score
from sklearn.naive_bayes import GaussianNB
import pandas as pa
import numpy as np

X, y, y_names, DESCR, f_names, _ =
    load_breast_cancer().values()

smooths = np.arange(1e-11, 1e-8, 1e-11)
cross = []
for s in smooths:
 model = GaussianNB(var_smoothing=s)
 c = cross_val_score(model, X, y, cv=5)
 cross.append([c.mean(), c])
df = pa.DataFrame(cross, columns=['M̩dia', 'Parti̵̤es'],
    index=smooths)

df[df['M̩dia'] == df['M̩dia'].max()]
# Out:
#  M̩dia
#     Parti̵̤es
# 2.230000e-09 0.940289 [0.9210526315789473,
#     0.9210526315789473, 0.947...
# 2.240000e-09 0.940289 [0.9210526315789473,
#     0.9210526315789473, 0.947...
# 2.250000e-09 0.940289 [0.9210526315789473,
#     0.9210526315789473, 0.947...
# 2.260000e-09 0.940289 [0.9210526315789473,
#     0.9210526315789473, 0.947...
# 2.270000e-09 0.940289 [0.9210526315789473,
#     0.9210526315789473, 0.947...
# 2.280000e-09 0.940289 [0.9210526315789473,
#     0.9210526315789473, 0.947...
# 2.290000e-09 0.940289 [0.9210526315789473,
#     0.9210526315789473, 0.947...
# 2.300000e-09 0.940289 [0.9210526315789473,
#     0.9210526315789473, 0.947...
# 2.310000e-09 0.940289 [0.9210526315789473,
#     0.9210526315789473, 0.947...
# 2.320000e-09 0.940289 [0.9210526315789473,
#     0.9210526315789473, 0.947...
# 2.330000e-09 0.940289 [0.9210526315789473,
#     0.9210526315789473, 0.947...
# 2.340000e-09 0.940289 [0.9210526315789473,
#     0.9210526315789473, 0.947...
# ...
